# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanhoe04/Netflix-2015-2021/blob/main/Gr%C3%A1ficos_Netflix%2BSifontes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Dataset Netflix 2015-2021

# %% [markdown]
# El dataset está en formato excel y contiene 26 columnas y mas de 9000 filas.
#
# •	Con esta base de dados se puede analizar cómo cambian las tendencias de las películas y programas de televisión con el tiempo. Por ejemplo, qué categorías de películas y programas de televisión son más populares en cada momento, o qué tipos de películas y programas de televisión son más propensos a ser vistos.
#
# •	Además, se puede analizar qué países o regiones son los que más ven las películas y programas de televisión de Netflix, o qué grupos demográficos son los que más interactúan con ellos.
#
# •	También que géneros son los mas premiados, los favoritos de los críticos y del público y cuales no, a fin de predecir que contenido puede ser el adecuado para seguir teniendo éxito en el futuro.

# %%
df = pd.read_excel("https://github.com/ivanhoe04/Netflix-2015-2021/raw/main/Netflix%20data.xlsx")

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# 9420                Comedy, Fantasy, Romance
# ...

# %%
df.shape
# Out:
# (9425, 26)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info
# Out:
# <bound method DataFrame.info of                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# ...

# %% [markdown]
# #Gráficos
