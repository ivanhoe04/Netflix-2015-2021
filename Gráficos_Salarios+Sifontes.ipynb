# %% [markdown]
# <a href="https://colab.research.google.com/github/ivanhoe04/Netflix-2015-2021/blob/main/Gr%C3%A1ficos_Salarios%2BSifontes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Dataset Salarios Profesionales 2017-2019

# %% [markdown]
# Este Dataset está en formato excel, tiene más de 6000 filas y 30 columnas, con información sobre salarios profesionales de personas de diferentes países, experiencia y roles dentro de organizaciones.
#
# •	Con esta base de dados se puede analizar cómo varían los salarios de acuerdo al país, a la profesión y experiencia.
#
# •	También que toman en cuenta las compañías para ser competitivas en cuanto a salarios y carrera profesional. Se puede analizar de acuerdo al seniority, cuantas personas puede un perfil tener a cargo.
#
# •	Además se puede analizar proyecciones de cómo pueden evolucionar los salarios a futuro tomando en cuenta años de experiencia y años dentro de una organización.

# %%
df1=pd.read_excel("https://github.com/ivanhoe04/Salarios-profesionales-2017-2019/raw/main/2019_Data_Professional_Salary_Survey_Responses.xlsx")

# %%
df1
# Out:
#         id  Survey Year            Timestamp SalaryUSD         Country  \
# 0        3         2017  2017-05-01 05:10:00    200000   United States
# 1        4         2017  2017-05-01 05:26:00     61515  United Kingdom
# 2        5         2017  2017-05-01 05:32:00     95000         Germany
# 3        6         2017  2017-05-01 05:33:00     56000  United Kingdom
# 4        7         2017  2017-05-01 05:34:00     35000          France
# ...    ...          ...                  ...       ...             ...
# 6888  6891         2019  2019-04-01 06:16:00     32000         Hungary
# 6889  6892         2019  2019-04-01 06:18:00     32000         Hungary
# 6890  6893         2019  2019-04-01 09:06:00     40000        Portugal
# 6891  6894         2019  2019-04-01 10:06:00    130000   United States
# 6892  6895         2019  2019-05-01 06:25:00     84500          Canada
#
#      PostalCode       PrimaryDatabase  YearsWithThisDatabase  \
# ...

# %%
df1.shape
# Out:
# (6893, 30)

# %%
type (df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.info
# Out:
# <bound method DataFrame.info of         id  Survey Year            Timestamp SalaryUSD         Country  \
# 0        3         2017  2017-05-01 05:10:00    200000   United States
# 1        4         2017  2017-05-01 05:26:00     61515  United Kingdom
# 2        5         2017  2017-05-01 05:32:00     95000         Germany
# 3        6         2017  2017-05-01 05:33:00     56000  United Kingdom
# 4        7         2017  2017-05-01 05:34:00     35000          France
# ...    ...          ...                  ...       ...             ...
# 6888  6891         2019  2019-04-01 06:16:00     32000         Hungary
# 6889  6892         2019  2019-04-01 06:18:00     32000         Hungary
# 6890  6893         2019  2019-04-01 09:06:00     40000        Portugal
# 6891  6894         2019  2019-04-01 10:06:00    130000   United States
# 6892  6895         2019  2019-05-01 06:25:00     84500          Canada
#
#      PostalCode       PrimaryDatabase  YearsWithThisDatabase  \
# ...

# %% [markdown]
# # Gráficos
